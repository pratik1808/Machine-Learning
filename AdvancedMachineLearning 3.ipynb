# %% [markdown]
# <b> MIS 382N: ADVANCED MACHINE LEARNING<b>
#
# Assignment 3
#
# Total points: 70
#
# Due: Monday, October 10 to be submitted via Canvas by 11:59 pm
#
# Your homework should be written in a python notebook. If you prefer, you can work in groups of two. **Please note that only one student per team needs to submit the assignment on Canvas but make sure to include both students' names and UT EIDs.**
#
# For any question that requires a handwritten solution, you may upload scanned images of your solution in the notebook or attach them to the assignment . You may write your solution using markdown as well.
#
# Please make sure your code runs and the graphs and figures are displayed in your notebook before submitting. (%matplotlib inline)

# %% [markdown]
# **This can be an individual assignment or group of 2. If you choose to do it as a group, please specify who you are working with (name and EID), then only one student should submit the homework. Put your name and eid here.**
#
# Name: Kavya Angara
#
# EID:ka32577
#
# Name: Pratik Gawli
#
# EID: pbg397

# %% [markdown]
# # Question 1: Tensorflow Playground (20 pts)
#
# In this question, you will be playing with [Tensorflow Playground](https://playground.tensorflow.org).
#
#
# Select "Classification" as the Problem Type. Among the four datasets shown in DATA, please select the top left dataset.
#
# Use the following settings as the DEFAULT settings for all subquestions: Learning rate = 0.03, Activation = Tanh, Regularization = None, Ratio of training to test data = 50%, Noise = 0, Batch Size = 30, input as  𝑋1  with  𝑋2 , One hidden layer with 4 neurons.
#
# #### a) (4 pts) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?
#
# #### We will now study the effect of certain variations in the network structure or training process, keeping all other aspects the same as in the DEFAULT setting specified above, with Tanh as the activation.
#
# Output for Tanh:
# Test loss 0.002
# Training loss 0.001
#
# Output for Linear:
# Test loss 0.501
# Training loss 0.500
#
# The decision boundary for the experiment which used Tanh as the activation function has well defined boundaries and classification of all datapoints is done accurately. For the experiment which used Linear activation function, the data points are not classified correctly and the decision boundary is not well defined.
#
# Reason for the difference between the 2 activation functions is because irrespective of how complex the architecture is, a linear activation function is effective only one layer deep and is linear whereas Tanh brings non linearity to the model.
#
#
# #### b) (4 pts) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?
#
# Output for 2 neurons:
# Test loss 0.252
# Training loss 0.155
#
# Output for 8 neurons:
# Test loss 0.00
# Training loss 0.00
#
# The decision boundary was not clear when 2 neurons were used whereas the decision boundary was very clear when 8 neurons were used. The model becomes more complex when 8 neurons are used as the data is split into multiple parts and result is thus converged into the optimal solution in minimum number of epochs. While using just 2 neurons, the data is more generalised. However, if we increase more neurons the model might overfit on the training data.
#
# #### c) (4 pts) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).
#
# **Learning rate 10**
# 1. Epoch 100 :
#    Test Loss 0.734
#    Train Loss 0.704
# 2. Epoch 500 :
#    Test Loss 0.721
#    Train Loss 1.701
# 3. Epoch 1000 :
#    Test Loss 0.703
#    Train Loss 0.698
#
# **Learning rate 1**
# 1. Epoch 100 :
#    Test Loss 0.145
#    Train Loss 0.090
# 2. Epoch 500 :
#    Test Loss 0.08
#    Train Loss 0.05
# 3. Epoch 1000 :
#    Test Loss 0.007
#    Train Loss 0.003
#
# **Learning rate 0.1**
# 1. Epoch 100 :
#    Test Loss 0.012
#    Train Loss 0.002
# 2. Epoch 500 :
#    Test Loss 0.005
#    Train Loss 0.001
# 3. Epoch 1000 :
#    Test Loss 0.004
#    Train Loss 0.000
#
# **Learning rate 0.01**
# 1. Epoch 100 :
#    Test Loss 0.20
#    Train Loss 0.144
# 2. Epoch 500 :
#    Test Loss 0.004
#    Train Loss 0.003
# 3. Epoch 1000 :
#    Test Loss 0.002
#    Train Loss 0.001
#
# **Learning rate 0.0001**
# 1. Epoch 100 :
#    Test Loss 0.500
#    Train Loss 0.500
# 2. Epoch 500 :
#    Test Loss 0.50
#    Train Loss 0.49
# 3. Epoch 1000 :
#    Test Loss 0.50
#    Train Loss 0.49
#
#
# Observations:
#
# Extreme learning rates like 10 (high) and 0.0001 (low) have very high losses. The lower learning rate changes very slowly after 1000 epochs whereas high learning rate fluctuates a lot hence is not able to reach optimum solution. Model reaches the optimal point slowly with learning rate 0.1 and does not fluctuate much whereas for learning rate 1 we can see fluctuations even after the model reaches the optimal point. However, learning rate 1 and 0.1 yield better results than learning rates 10 and 0.0001.
#
# #### d) (4 pts) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.
#
# Output for single hidden layer with 4 neurons:
# Test loss 0.004
# Training loss 0.001
#
# Output for 2 hidden layers with 3 neurons:
# Test loss 0.002
# Training loss 0.001
#
# The model with 2 hidden layers reached the optimum solution faster than the model with single hidden layer. This suggests that the model with 2 layers is more efficient than the model with 1 layer. Both the models defined the decision boundaries and the training and test losses were also similar.
#
# #### e) (4 pts) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as  sin(𝑋1),𝑋21  etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.

# %% [markdown]
# ![Screen%20Shot%202022-10-10%20at%203.59.29%20PM.png](attachment:Screen%20Shot%202022-10-10%20at%203.59.29%20PM.png)

# %% [markdown]
# We have used learning rate 0.03, Activation as Tanh, Features as x1^2 and x2^2 and 1 hidden layer with 1 neuron. We got Test loss and train loss as 0 within 320 epochs. This is a simple model and can be suggested as the best solution.
#
# However, we can make the model give 0.00 test loss (as below) by making the model more complicated but it may cost us computational costs.

# %% [markdown]
# ![Screen%20Shot%202022-10-10%20at%204.05.18%20PM.png](attachment:Screen%20Shot%202022-10-10%20at%204.05.18%20PM.png)

# %% [markdown]
# Here we have used learning rate 0.1, Activation as Tanh, regularization as L2, Features as x2, x1x2, x1^2 and x2^2 and 1 hidden layer with 4 neuron. We got Test loss and train loss as 0 within 98 epochs. This is a complex model.

# %% [markdown]
# ![Screen%20Shot%202022-10-10%20at%204.06.16%20PM.png](attachment:Screen%20Shot%202022-10-10%20at%204.06.16%20PM.png)

# %% [markdown]
# Similarily, here we have used learning rate 0.1, Activation as Tanh, regularization as L1, Features as x2, x1x2, x1^2 and x2^2 and 1 hidden layer with 8 neuron. We got Test loss and train loss as 0 within 88 epochs. This is a complex model.

# %% [markdown]
# # Question 2 : t-SNE (7 pts)
#
# #### Read this [article](https://erdem.pl/2020/04/t-sne-clearly-explained) on t-SNE, a dimensionality reduction technique for visualization and explain it in your own words in one or two paragraphs.

# %% [markdown]
# #### Answer:
#
#
# t-distributed Stochastic Neighbor Embedding is used to seperate non-linear data. It helps in nonlinear dimensionality reduction i.e. it projects the high-dimensional data to low dimension and can be used in problems like CNN. t-SNE is iterative so unlike PCA we cannot apply it on another dataset. It’s not deterministic and iterative so each time it runs, it could produce a different result and due to this reason it cannot be used in Machine Learning models.
#
# Example of a problem that SNE solves is - if we project multi dimension clusters on one of the axis, the clusters will not be clear and accurate and they all will be convoluted. T-SNE projects the clusters in multi dimensional space such that the clusters are accurate and potray correct information. The process/algorithm first maps all the points of scatter plot on number Line. They are plotted in random order. t-SNE then moves every point on number line till it clusters them. For a particcular point it sees which points are attracted by it and which points are repelled and then assigns accordingly. It moves on the basis of attraction and moves closer when attraction is strongest,else moves away. This happenes in an iterative way till all the points are clustered.

# %% [markdown]
# # Question 3: PCA (8 pts)
#
# Explain the principle of Principal Component Analysis algorithm and in what sense is the selection of the eigenvectors to represent the data is an optimal choice.  How do you reconstruct (a noisy version of) the original data from the eigenvectors and the loadings?

# %% [markdown]
# #### Answer:
#
# Principal component analysis (PCA) is a statistical procedure that is used to reduce the dimensionality. The steps taken by PCA to do the same are as follows:
# 1. PCA computes eigenvectors of the covariance matrix, which can be referred as "principal axes"
# 2. It the sorts the "principal axes" by their eigenvalues. Eigenvalues is basically the amount of explained variance.
# 3. The centered data can then be projected onto these principal axes to yield principal components. The prinicpal components are the "scores".
# 4. For the purposes of dimensionality reduction, one can keep only a subset of principal components and discard the rest.
#
# The above steps can be explained algorithmically below:
#
# 1. Let 𝐗1 be the 𝑛×𝑝 data matrix with 𝑛 rows, each row is a data point and 𝑝 columns, where each column represents a variable or a feature.
# 2. After subtracting the mean vector 𝝁 from each row, we get the centered data matrix 𝐗1.
# 3. Let 𝐕 be the 𝑝×𝑘 matrix of some 𝑘 eigenvectors that we want to use; these would most often be the 𝑘 eigenvectors with the largest eigenvalues. The selection of only the vectors we would like to use results ultimately in dimension reduction
# 4. Then the 𝑛×𝑘 matrix of PCA projections will be simply given by 𝐙=𝐗1𝐕. These PCA projections are the "scores"
#
# The reason we use eigenvectors is to calculate distances between data points. This can be useful when creating models that need to group data points based on similarity. Eigenvalues can hence be used as weights in PCA and can be the optimal choice.
#
# In order to be able to reconstruct the original data from principal components, lets consider the above algorithm's output and follow the steps:
# 1. We can map the 𝐙 matrix back to 𝑝 dimensions with transpose of 𝐕.
# 2. The values of each principal component should be placed on the same vector as was used for projection
# 3. The original matrix is then given by 𝐗̂2 =𝐙(transpose of 𝐕) = 𝐗𝐕𝐕⊤.
# 4. To get the final reconstruction 𝐗̂1, we need to add the mean vector 𝝁 to that as follows :
#        PCA reconstruction=PC scores⋅(Transpose of Eigenvectors)+Mean

# %% [markdown]
# # Question 4: Outlier detection using PyOD (20 pts)
#
# Outlier detection, or anomaly detection is usually an unsupervised learning task where the objective is to identify suspicious observations in data. It has been widely used in military surveillance for enemy activities to prevent attacks, intrusion detection in cyber security, fraud detection for credit cards, etc.
#
# PyOD is a comprehensive and scalable Python library for detecting outlying objects in multivariate data. PyOD includes more than 30 detection algorithms and provides unified APIs which makes it quite handy to use. In this question, you will play with PyOD, explore three different outlier detection algorithms and compare their performances. First let's install PyOD.
#
# ```
# # install pyod using pip first
# !pip install pyod
# ```
#
# You can load the data stored in 'Q3_train_dataset.csv' and 'Q3_test_dataset.csv' using the following codes.
#
# ```
# import pandas as pd
# # Load data code goes here
# train_df = pd.read_csv('Q3_train_dataset.csv')
# test_df = pd.read_csv('Q3_test_dataset.csv')
#
# X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
# y_train = train_df[['y_train']].to_numpy()
# X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
# y_test = test_df[['y_test']].to_numpy()
# ```
#
#  `X_train` and `X_test` contain the features, with the dimension of 5. `y_train` and `y_test` store the outlier labels, 0 means normal data, 1 means outlier data.
#
# a) **(5 pts)** **Fit `X_train` to a outlier detection model k Nearest Neighbors (kNN) using PyOD**, this [page](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.mcd) will provide some functions you may need.
#
# ```
# from pyod.models.knn import KNN
# clf = KNN() # initialize KNN class using the default parameters
#
# # YOUR CODE SHOULD COME HERE, FIT THE MODEL USING X_TRAIN
# ```
# **Use the fitted model to predict the outlier labels of `X_test`. Compute the raw outlier scores on `X_test` using `decision_function()`.**
#
# **Run PyOD's `evaluate_print()` function using the test set ground truth outlier labels and the raw outlier scores predicted by the model, to compute the ROC and Precision@n results .**
#
# ```
# from pyod.utils.data import evaluate_print
# ```
#
# b) **(5 pts)** `X_train` and `X_test` are 5-dimension features, which makes it impossible to visualize them in Euclidean plane. But we can use Principal Component Analysis (PCA) to reduce the dimensions of `X_train` and `X_test` to 2, and then plot them. You may want to use `fit_and_transform()` function.
#
#
# ```
# from sklearn.decomposition import PCA
#
# pca = PCA(n_components=2)
#
# # Fit pca to X_train and X_test and transform
# train_principalComponents = # IMPLEMENT
# test_principalComponents = # IMPLEMENT
# ```
#
# After reducing the dimension to 2, now you can visualize the outliers using PyOD's `visualize()` function. Please plot the visualization. You may find [this](https://pyod.readthedocs.io/en/latest/pyod.utils.html#module-pyod.utils.example) useful on how to use `visualize()` .
#
# ```
# from pyod.utils.example import visualize
# ```
#
# Now you should be able to observe the ground truth outliers and the outliers predicted by the model.
#
#
# c) **(10 pts)** Apply the same process as in (a) and (b) to the following two models, and visualize the outlier results. Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.
#
# *   [Isolation-Based model - Isolation-based anomaly detection using Nearest-Neighbor Ensembles (INNE)](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.inne)
#
# ```
# from pyod.models.inne import INNE
# ```
#
# # Answer:

# %%
# install pyod using pip first
# !pip install pyod

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Load data code goes here
train_df = pd.read_csv('Q3_train_dataset.csv')
test_df = pd.read_csv('Q3_test_dataset.csv')

X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
y_train = train_df[['y_train']].to_numpy()
X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
y_test = test_df[['y_test']].to_numpy()

# %%
# (a)
from pyod.models.knn import KNN
clf = KNN() # initialize KNN class using the default parameters

# fit the model using X_train

# YOUR CODE SHOULD COME HERE
clf.fit(X_train)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
from pyod.utils.data import evaluate_print
# predict the outlier labels of X_test using the trained model, compute the raw outlier scores on X_test using decision_function()
# then use evaluate_print() to print out the evaluation results

# YOUR CODE SHOULD COME HERE
clf.predict(X_test)
clf.decision_function(X_test)
evaluate_print(clf, y_test, clf.decision_function(X_test))
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0) ROC:0.9044, precision @ rank n:0.5

# %%
# (b)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = pca.fit_transform(X_train) # YOUR CODE SHOULD COME HERE
test_principalComponents = pca.fit_transform(X_test) # YOUR CODE SHOULD COME HERE

from pyod.utils.example import visualize
# Visualize the ground truth outliers and predicted outliers using visualize()

# YOUR CODE SHOULD COME HERE
clf =KNN()
clf.fit(X_train, y_train)
visualize(
    clf_name=clf,
    X_train=train_principalComponents, 
    y_train=y_train, 
    X_test=test_principalComponents, 
    y_test=y_test, 
    y_train_pred=clf.predict(X_train), 
    y_test_pred=clf.predict(X_test))

# %%
# (c)
from pyod.models.inne import INNE

clf =INNE()
clf.fit(X_train)

clf.predict(X_test)
clf.decision_function(X_test)
evaluate_print(clf, y_test, clf.decision_function(X_test))
# Out:
# INNE(contamination=0.1, max_samples='auto', n_estimators=200,
#    random_state=None) ROC:0.8578, precision @ rank n:0.6

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = pca.fit_transform(X_train) # YOUR CODE SHOULD COME HERE
test_principalComponents = pca.fit_transform(X_test) # YOUR CODE SHOULD COME HERE

from pyod.utils.example import visualize
# Visualize the ground truth outliers and predicted outliers using visualize()

# YOUR CODE SHOULD COME HERE
clf =INNE()
clf.fit(X_train, y_train)
visualize(
    clf_name=clf,
    X_train=train_principalComponents, 
    y_train=y_train, 
    X_test=test_principalComponents, 
    y_test=y_test, 
    y_train_pred=clf.predict(X_train), 
    y_test_pred=clf.predict(X_test))

# %% [markdown]
# ## Please compare the performance of the two models in terms of their ROC, Precision@n, and what you observe from the two visualizations.
#
# ROC for KNN: 0.9044
# ROC for INNE: 0.8578
#
# precision @ rank n for KNN: 0.5
# precision @ rank n for INNE: 0.6
#
# For this particular dataset, KNN appears to be performing better than INNE as its ROC value is greater, indicating that overall the true positive rate is higher and the false positive rate is lower than for INNE.
#
# However, precision @ rank n is higher for INNE than KNN. Meaning of the proportion of outlier predicted by INNE being actually outliers is greater than the same ratio of KNN.
#
# As seen in the above plots, after dimensionality reduction, KNN does a pretty fair job and not exceptionally well on detecting outliers on both test and training datasets because visually, it can be seen that the rate of misclassifying an outlier as an inlier is higher than that of misclassifying inlier as an outlier. Also, INNE is misclassifying inliers which lie in the middle of the clusters to be as outliers, hampering its ROC compared to KNN.

# %% [markdown]
# # Question 5: Pre-processing and sampling (15 pts)
#
# The following dataset contains House prices describing the sales of individual residential property in Ames, Iowa data with explanatory variables describing almost every aspect of residential homes and dependent variable being SalePrice. Here, some cells of most columns in the dataset contain NaN values.

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
np.random.seed(100)

data = pd.read_csv("sales_data.csv")
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  \
# 0             60       RL         65.0     8450   NaN            7
# 1             20       RL         80.0     9600   NaN            6
# 2             60       RL         68.0    11250   NaN            7
# 3             70       RL         60.0     9550   NaN            7
# 4             60       RL         84.0    14260   NaN            8
# ...          ...      ...          ...      ...   ...          ...
# 1455          60       RL         62.0     7917   NaN            6
# 1456          20       RL         85.0    13175   NaN            6
# 1457          70       RL         66.0     9042   NaN            7
# 1458          20       RL         68.0     9717   NaN            5
# 1459          20       RL         75.0     9937   NaN            5
#
#       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ... 3SsnPorch  \
# 0               5       2003          2003       196.0  ...         0
# ...

# %% [markdown]
# a)**(2 pts)**Print the number of NaN, NULL and empty values (combined sum) in each column.

# %%
data.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Alley            1369
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea          8
# ExterQual           0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageCars          0
# GarageArea          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ...

# %% [markdown]
# b)**(3 pts)**Create a copy of `data`, and name it `data_dm`, then create a new column in `data_dm` named `binned_garage_yr_built` and apply binning to the column `garage_yr_built`. Use `pandas.cut()` and modify its parameter list as below:
#
# ```
# bins=[1900, 1930, 1960, 1990, 2020]
# labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
# include_lowest=True
# ```
# Next, perform one-hot encoding on this new column.

# %%
data_dm = data.copy()
data_dm['binned_garage_yr_built'] = pd.cut(data_dm['GarageYrBlt'],
                                    bins=[1900, 1930, 1960, 1990, 2020],
                                    labels=['1900-1930', '1930-1960', '1960-1990', '1990-2000'],
                                    include_lowest=True)

#One hot encoding
binned_garage_yr_dummies = pd.get_dummies(data_dm['binned_garage_yr_built'],drop_first=True)
data_dm.drop('GarageYrBlt', axis=1, inplace = True) #removing redundant column
data_dm = pd.concat([data_dm, binned_garage_yr_dummies], axis=1)
data_dm
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  \
# 0             60       RL         65.0     8450   NaN            7
# 1             20       RL         80.0     9600   NaN            6
# 2             60       RL         68.0    11250   NaN            7
# 3             70       RL         60.0     9550   NaN            7
# 4             60       RL         84.0    14260   NaN            8
# ...          ...      ...          ...      ...   ...          ...
# 1455          60       RL         62.0     7917   NaN            6
# 1456          20       RL         85.0    13175   NaN            6
# 1457          70       RL         66.0     9042   NaN            7
# 1458          20       RL         68.0     9717   NaN            5
# 1459          20       RL         75.0     9937   NaN            5
#
#       OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  ...  Fence  \
# 0               5       2003          2003       196.0  ...    NaN
# ...

# %% [markdown]
# c)**(3 pts)**Drop the columns which have more than 90%, 95% and 98% of missing values. List the columns which get dropped in each of the cases and observe the number of columns that get dropped in each of the cases as well.

# %%
drop_90 = (data_dm.isna().sum() / data_dm.shape[0] > 0.90)
drop_90[drop_90]
# Out:
# Alley          True
# PoolQC         True
# MiscFeature    True
# dtype: bool

# %%
drop_95 = (data_dm.isna().sum() / data_dm.shape[0] > 0.95)
drop_95[drop_95]
# Out:
# PoolQC         True
# MiscFeature    True
# dtype: bool

# %%
drop_98 = (data_dm.isna().sum() / data_dm.shape[0] > 0.99)
drop_98[drop_98]
# Out:
# PoolQC    True
# dtype: bool

# %% [markdown]
# As we can see above, on dropping columns which has more than 90% data missing, we remove 3 Columns(Alley, PoolQC and MiscFeature).
# On dropping columns which has more than 95% data missing, we remove 2 Columns(PoolQC, MiscFeature).
# on dropping columns which has more than 98% data missing, we remove 1 Column(PoolQC).

# %% [markdown]
# d)**(2 pts)**Take a sample of 800 rows at random and compute its mean. Compare the result with the population mean

# %%
np.random.seed(18)
sample_set = np.random.choice(a= data['SalePrice'], size=800)
#Sample mean
sample_mean = np.mean(sample_set)
#Population mean
population_mean = np.mean(data_dm['SalePrice'])

print("Sample Mean: ", str(sample_mean)+"\nPopulation Mean: "+str(population_mean))
# Out:
# Sample Mean:  184220.3875
# Population Mean: 180921.19589041095

# %% [markdown]
# As we can see above, the sample mean and population mean of the SalePrice are quite close to each other, but not exactly the same. This was expected as the sample will only give the estimate of the mean, not the actual mean of the population which is calculated by considering all samples

# %% [markdown]
# e) i)**(2pts)** Calculate 95% confidence intervals for SalePrice with a sample size of 100.
#
# ii)**(3pts)** Calculate 95 % confidence intervals for 100 different trials with a sample size of 500. Plot the confidence intervals and interpret how it captures the population mean.

# %%
np.random.seed(10)
sample_size = 100
sample = np.random.choice(a= data_dm['SalePrice'],
                          size = sample_size)
sample_mean = sample.mean()

#Get the critical Z value
z_critical = 1.96 # for 95 % confidence interval

#Get population standard deviation
pop_stdev = np.std(data['SalePrice'])

#margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size)) 

#confidence interval
confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error)  

#Print confidence interval and true mean value
print("Confidence Interval :",confidence_interval)
print("Population Mean :",population_mean)
# Out:
# Confidence Interval : (166527.13279033077, 197657.92720966923)
# Population Mean : 180921.19589041095

# %%
np.random.seed(12)

#define the sample size
sample_size=500
intervals = []
sample_means = []
z_critical = 1.96 #intializing outsize loop as it's fixed for a 95% interval
pop_stdev = np.std(data['SalePrice']) #calculating outside the loop as SD of population does not change with sample

for sample in range(100):
    sample = np.random.choice(a= data_dm['SalePrice'], size = sample_size)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)
    margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))
    confidence_interval = (sample_mean - margin_of_error,
                           sample_mean + margin_of_error)  
    intervals.append(confidence_interval)
    
plt.figure(figsize=(13, 9))

plt.errorbar(x=np.arange(0.1, 100, 1), 
             y=sample_means, 
             yerr=[(top-bot)/2 for top,bot in intervals],
             fmt='o')

plt.hlines(xmin=0, xmax=100,
           y=data['SalePrice'].mean(), 
           linewidth=2.0,
           color="red")
plt.title('Confidence Intervals for 100 Trials', fontsize = 20)
plt.show()

# %% [markdown]
# As we can see above, sample mean of the samples taken are approximately around the value of the population mean(redline). This verifies the Central Limit Theorem and sampling theory as well. This suggests that in real world datasets, where we do not have actual whole population data, we can use the sample mean and other metrics and specify the confidence interval to arrive at insightful results.
